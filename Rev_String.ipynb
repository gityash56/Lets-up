# %%
def reverse(s):
	str = ""
	for i in s:
		str = i + str
	return str

s = "LetsUpgrade"

print("The original string is : ", end="")
print(s)

print("The reversed string(using loops) is : ", end="")
print(reverse(s))
# Out:
# The original string is : LetsUpgrade
# The reversed string(using loops) is : edargpUsteL
